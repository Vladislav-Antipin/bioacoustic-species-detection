# %%
import librosa
import librosa.display
import scipy
import matplotlib.pyplot as plt
import numpy as np
import os
# import kagglehub
# kagglehub.competition_download('birdclef-2026', output_dir="../data")

# %% [markdown]
# Features that can be extracted from sound:
# - raw signal features:
#     - mean, variance
#     - zero-crossing rate
# - frequency based:
#     - spectral features
#         - spectral centroid
#         - spectral bandwidth
#         - spectral rolloff ?
#     - MFCC: Mel_Frequency Cepstral Coefficients ...
# - time-frequency features:
#     - spectrogram stats
#     - chroma features

# %%
# y, sr = librosa.load("../data/train_soundscapes/BC2026_Train_10595_S19_20241215_193000.ogg")
# Out:
# (1323000,)

# %%
for fname in sorted(os.listdir("../data/train_soundscapes/"))[:10]:
    y, sr = librosa.load("../data/train_soundscapes/"+fname)
    # print(y.shape)
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)
    features = mfcc.mean(axis=1)
    S = librosa.stft(y)
    S_db = librosa.amplitude_to_db(np.abs(S), ref=np.max)
    plt.imshow(S_db)
    plt.title(fname)
    plt.show()

# %%
for TRAIN_DIR in ("../data/train_audio/22930/", "../data/train_soundscapes/"):
    for fname in sorted(os.listdir(TRAIN_DIR))[:10]:
        y, sr = librosa.load(TRAIN_DIR+fname)
        # print(y.shape)
        mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)
        features = mfcc.mean(axis=1)
        S = librosa.stft(y)
        S_db = librosa.amplitude_to_db(np.abs(S), ref=np.max)
        plt.imshow(S_db)
        plt.title(fname)
        plt.show()
